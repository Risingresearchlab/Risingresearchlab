# %% [markdown]
# <a href="https://colab.research.google.com/github/Risingresearchlab/Risingresearchlab/blob/main/yolo_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/Yolo_training')

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
#!git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16965, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 16965 (delta 82), reused 100 (delta 49), pack-reused 16805 (from 1)
# Receiving objects: 100% (16965/16965), 15.70 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (11611/11611), done.
# Updating files: 100% (147/147), done.

# %%
os.chdir('/content/drive/MyDrive/Yolo_training/yolov5')

# %%
ls
# Out:
# benchmarks.py    data/         export.py   __pycache__/     requirements.txt  tutorial.ipynb
# CITATION.cff     data_images/  hubconf.py  pyproject.toml   runs/             utils/
# classify/        data.yaml     LICENSE     README.md        segment/          val.py
# CONTRIBUTING.md  detect.py     models/     README.zh-CN.md  train.py          yolov5s.pt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 36.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# ## Training yolo v5 model

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 15
#!python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 5 --name Model --epochs 3
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        5/14       2.5G    0.04044    0.02753    0.01037         60        640:  78% 207/267 [11:26<03:10,  3.18s/it]/content/drive/MyDrive/Yolo_training/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/14       2.5G    0.04044    0.02753    0.01036         42        640:  78% 208/267 [11:28<02:59,  3.05s/it]/content/drive/MyDrive/Yolo_training/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
